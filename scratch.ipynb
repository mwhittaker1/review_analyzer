# %%
import pandas as pd

# %%
csv1 = r"C:\Code\URBN\RETRO_hack_25\data\IID_30K_RETURN_REASON.csv"
csv2 = r"C:\Code\URBN\RETRO_hack_25\data\IID_30k.csv"
df_return_reason = pd.read_csv(csv1)
df_iid = pd.read_csv(csv2)
# Out:
# C:\Users\MWOfficeDesktop\AppData\Local\Temp\ipykernel_58324\3667144781.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_return_reason = pd.read_csv(csv1)
# C:\Users\MWOfficeDesktop\AppData\Local\Temp\ipykernel_58324\3667144781.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_iid = pd.read_csv(csv2)
# C:\Users\MWOfficeDesktop\AppData\Local\Temp\ipykernel_58324\3667144781.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_iid = pd.read_csv(csv2)
# df_return_reason total rows: 2040557
# df_iid total rows: 3837373
#
# No 'iid' column found in df_return_reason
# ...

# %%
# Display total row count for each DataFrame
print(f"df_return_reason total rows: {len(df_return_reason)}")
print(f"df_iid total rows: {len(df_iid)}")

# Count distinct IID values in each DataFrame
# Assuming the column name is 'iid' - adjust if it has a different name
if 'IID' in df_return_reason.columns:
    distinct_iids_return = df_return_reason['IID'].nunique()
    print(f"\nDistinct IID count in df_return_reason: {distinct_iids_return}")
else:
    print("\nNo 'iid' column found in df_return_reason")
    # List available columns to help identify the correct column name
    print(f"Available columns in df_return_reason: {df_return_reason.columns.tolist()}")

if 'IID' in df_iid.columns:
    distinct_iids = df_iid['IID'].nunique()
    print(f"Distinct IID count in df_iid: {distinct_iids}")
else:
    print("No 'IID' column found in df_iid")
    # List available columns to help identify the correct column name
    print(f"Available columns in df_iid: {df_iid.columns.tolist()}")

# Display descriptive statistics
print("\ndf_return_reason descriptive statistics:")
print(df_return_reason.describe())
print("\ndf_iid descriptive statistics:")
print(df_iid.describe())
# Out:
# df_return_reason total rows: 2040557
# df_iid total rows: 3837373
#
# Distinct IID count in df_return_reason: 29870
# Distinct IID count in df_iid: 28497
#
# df_return_reason descriptive statistics:
# Distinct IID count in df_iid: 28497
#
# df_return_reason descriptive statistics:
#           SALES_QTY    RETURN_QTY   MAX(RR.F_ID)  \
# count  2.040557e+06  2.040557e+06  429454.000000
# mean   1.057097e+00  2.141900e-01      10.703901
# std    9.060043e-01  4.268146e-01      10.917771
# min    1.000000e+00  0.000000e+00       2.000000
# 25%    1.000000e+00  0.000000e+00       2.000000
# 50%    1.000000e+00  0.000000e+00       2.000000
# 75%    1.000000e+00  0.000000e+00      14.000000
# max    5.970000e+02  2.000000e+01      44.000000
#
#        MAX(RR.Q_D2C_RTRN_REASONCODE_ID)  MAX(RR.Q_D2C_RET_REASON)  \
# count                      4.294540e+05             429454.000000
# mean                       5.470468e+07                206.282044
# ...
